# %%
import sqlite3
from pathlib import Path
import numpy as np
import pandas as pd

# %%
db_path = Path("../../data/database.sqlite")
conn = sqlite3.connect(db_path.as_posix())
df = pd.read_sql_query("SELECT * FROM Match_Aggregated", conn)
conn.close()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 427220 entries, 0 to 427219
# Data columns (total 84 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   match_api_id                              427220 non-null  int64
#  1   date                                      427220 non-null  str
#  2   position_col                              427220 non-null  str
#  3   player_api_id                             427220 non-null  int64
#  4   team_side                                 427220 non-null  str
#  5   position_no                               427220 non-null  int64
#  6   id                                        427220 non-null  int64
#  7   player_fifa_api_id                        427220 non-null  int64
#  8   overall_rating                            427220 non-null  float64
#  9   potential                                 427220 non-null  float64
#  10  preferred_foot                            427220 non-null  float64
#  11  attacking_work_rate                       427220 non-null  float64
#  12  defensive_work_rate                       427220 non-null  float64
#  13  crossing                                  427220 non-null  float64
#  14  finishing                                 427220 non-null  float64
#  15  heading_accuracy                          427220 non-null  float64
#  16  short_passing                             427220 non-null  float64
#  17  volleys                                   427220 non-null  float64
#  18  dribbling                                 427220 non-null  float64
#  19  curve                                     427220 non-null  float64
#  20  free_kick_accuracy                        427220 non-null  float64
#  21  long_passing                              427220 non-null  float64
#  22  ball_control                              427220 non-null  float64
#  23  acceleration                              427220 non-null  float64
#  24  sprint_speed                              427220 non-null  float64
#  25  agility                                   427220 non-null  float64
#  26  reactions                                 427220 non-null  float64
#  27  balance                                   427220 non-null  float64
#  28  shot_power                                427220 non-null  float64
#  29  jumping                                   427220 non-null  float64
#  30  stamina                                   427220 non-null  float64
#  31  strength                                  427220 non-null  float64
#  32  long_shots                                427220 non-null  float64
#  33  aggression                                427220 non-null  float64
#  34  interceptions                             427220 non-null  float64
#  35  positioning                               427220 non-null  float64
#  36  vision                                    427220 non-null  float64
#  37  penalties                                 427220 non-null  float64
#  38  marking                                   427220 non-null  float64
#  39  standing_tackle                           427220 non-null  float64
#  40  sliding_tackle                            427220 non-null  float64
#  41  player_name                               427220 non-null  str
#  42  height                                    427220 non-null  float64
#  43  weight                                    427220 non-null  int64
#  44  home_team_api_id                          427220 non-null  int64
#  45  away_team_api_id                          427220 non-null  int64
#  46  home_team_goal                            427220 non-null  int64
#  47  away_team_goal                            427220 non-null  int64
#  48  home_team_id                              425880 non-null  float64
#  49  home_team_team_fifa_api_id                425880 non-null  float64
#  50  home_team_team_date                       425880 non-null  str
#  51  home_team_buildUpPlaySpeed                425880 non-null  float64
#  52  home_team_buildUpPlayDribbling            425880 non-null  float64
#  53  home_team_buildUpPlayPassing              425880 non-null  float64
#  54  home_team_buildUpPlayPositioningClass     425880 non-null  float64
#  55  home_team_chanceCreationPassing           425880 non-null  float64
#  56  home_team_chanceCreationCrossing          425880 non-null  float64
#  57  home_team_chanceCreationShooting          425880 non-null  float64
#  58  home_team_chanceCreationPositioningClass  425880 non-null  float64
#  59  home_team_defencePressure                 425880 non-null  float64
#  60  home_team_defenceAggression               425880 non-null  float64
#  61  home_team_defenceTeamWidth                425880 non-null  float64
#  62  home_team_defenceDefenderLineClass        425880 non-null  float64
#  63  home_team_team_long_name                  425880 non-null  str
#  64  home_team_team_short_name                 425880 non-null  str
#  65  away_team_id                              426000 non-null  float64
#  66  away_team_team_fifa_api_id                426000 non-null  float64
#  67  away_team_team_date                       426000 non-null  str
#  68  away_team_buildUpPlaySpeed                426000 non-null  float64
#  69  away_team_buildUpPlayDribbling            426000 non-null  float64
#  70  away_team_buildUpPlayPassing              426000 non-null  float64
#  71  away_team_buildUpPlayPositioningClass     426000 non-null  float64
#  72  away_team_chanceCreationPassing           426000 non-null  float64
#  73  away_team_chanceCreationCrossing          426000 non-null  float64
#  74  away_team_chanceCreationShooting          426000 non-null  float64
#  75  away_team_chanceCreationPositioningClass  426000 non-null  float64
#  76  away_team_defencePressure                 426000 non-null  float64
#  77  away_team_defenceAggression               426000 non-null  float64
#  78  away_team_defenceTeamWidth                426000 non-null  float64
#  79  away_team_defenceDefenderLineClass        426000 non-null  float64
#  80  away_team_team_long_name                  426000 non-null  str
#  81  away_team_team_short_name                 426000 non-null  str
#  82  player_x                                  427220 non-null  float64
#  83  player_y                                  427220 non-null  float64
# dtypes: float64(64), int64(10), str(10)
# memory usage: 273.8 MB

# %% [markdown]
# # Extract Player Stats

# %%
player_stats_cols = [
    "preferred_foot",
    "attacking_work_rate",
    "defensive_work_rate",
    "crossing",
    "finishing",
    "heading_accuracy",
    "short_passing",
    "volleys",
    "dribbling",
    "curve",
    "free_kick_accuracy",
    "long_passing",
    "ball_control",
    "acceleration",
    "sprint_speed",
    "agility",
    "reactions",
    "balance",
    "shot_power",
    "jumping",
    "stamina",
    "strength",
    "long_shots",
    "aggression",
    "interceptions",
    "positioning",
    "vision",
    "penalties",
    "marking",
    "standing_tackle",
    "sliding_tackle",
]

# Create a copy to avoid SettingWithCopy warnings
df_processed = df.copy()

# Scale work rates from [0, 2] to [-1, 1]
df_processed[["attacking_work_rate", "defensive_work_rate"]] = (
    df_processed[["attacking_work_rate", "defensive_work_rate"]] - 1
)

# Scale attributes from [0, 100] to [-1, 1]
scale_cols = player_stats_cols[3:]
df_processed[scale_cols] = (df_processed[scale_cols] / 50) - 1

# %%
formation_data_list = []

print("Processing 10-player formations (outfield only)...")

# Group by match and team
for (match_id, team_side), df_group in df_processed.groupby(
    ["match_api_id", "team_side"]
):
    # Since you ignore the GK, you expect 10 players.
    # We'll allow a small buffer just in case of red cards/missing data.
    if len(df_group) < 10:
        continue

    # Extract positions and stats
    np_pos = df_group[["player_x", "player_y"]].to_numpy()
    np_stats = df_group[player_stats_cols].to_numpy()

    # Normalize Positions globally (x: 1-9, y: 3-11)
    np_pos_norm = np_pos.copy().astype(float)
    np_pos_norm[:, 0] = (np_pos_norm[:, 0] - 5.0) / 4.0
    np_pos_norm[:, 1] = (np_pos_norm[:, 1] - 7.0) / 4.0

    # Process each of the 10 players
    for i in range(len(df_group)):
        current_player_stats = np_stats[i]
        current_player_pos = np_pos_norm[i]

        # Get relative positions of the other 9 teammates
        teammates_pos = np.delete(np_pos_norm, i, axis=0)

        # If there are exactly 10 players, teammates_pos will be exactly 9.
        # If there are more (e.g. 11), we take the 9 closest.
        if len(teammates_pos) > 9:
            diffs = teammates_pos - current_player_pos
            dists = np.linalg.norm(diffs, axis=1)
            closest_idx = np.argsort(dists)[:9]
            teammates_pos = teammates_pos[closest_idx]

        relative_vectors = teammates_pos - current_player_pos

        # Calculate Distances and Angles
        distances = np.linalg.norm(relative_vectors, ord=2, axis=1) / 2.5
        angles_rad = np.arctan2(relative_vectors[:, 1], relative_vectors[:, 0]) / np.pi

        # Combine: Stats + Global Pos + Distances + Angles
        row = np.hstack(
            [match_id, current_player_stats, current_player_pos, distances, angles_rad]
        )
        formation_data_list.append(row)
# Out:
# Processing 10-player formations (outfield only)...

# %%
formation_cols = (
    ["x", "y"]
    + [f"distance_{i + 1}" for i in range(9)]
    + [f"angle_{i + 1}" for i in range(9)]
)

df_final = pd.DataFrame(
    formation_data_list, columns=["match_api_id"] + player_stats_cols + formation_cols
)

# %%
df_final.shape
# Out:
# (427220, 52)

# %%
df_final.head()
# Out:
#    match_api_id  preferred_foot  attacking_work_rate  defensive_work_rate  \
# 0      483130.0             1.0                  0.0                  1.0
# 1      483130.0             0.0                  0.0                  0.0
# 2      483130.0             0.0                  0.0                  1.0
# 3      483130.0             1.0                  0.0                  0.0
# 4      483130.0             0.0                 -1.0                  0.0
#
#    crossing  finishing  heading_accuracy  short_passing  volleys  dribbling  \
# 0      0.48      -0.14              0.20           0.30    -0.60       0.14
# 1      0.32       0.18             -0.36           0.46     0.34       0.28
# 2      0.44       0.26             -0.24           0.26    -0.16       0.38
# 3      0.40       0.08              0.20           0.60     0.18       0.28
# 4      0.48      -0.14              0.04           0.76    -0.04      -0.16
#
#    ...  distance_9   angle_1   angle_2   angle_3   angle_4   angle_5  \
# 0  ...    0.400000  0.000000  0.250000  0.187167  0.352416  0.000000
# 1  ...    0.200000  1.000000  0.647584  0.500000  0.750000  1.000000
# 2  ...    0.400000 -0.750000 -0.352416  0.000000  1.000000 -0.647584
# 3  ...    0.447214 -0.812833 -0.500000  1.000000  1.000000 -0.750000
# 4  ...    0.447214 -0.647584 -0.250000  0.000000  0.000000 -0.500000
#
#     angle_6   angle_7   angle_8   angle_9
# 0  0.500000  0.411414  0.334751  0.000000
# 1  0.812833  0.665249  0.588586  1.000000
# 2  1.000000  0.687167  0.500000 -0.500000
# 3  1.000000  0.795167  0.687167 -0.647584
# 4  1.000000  0.500000  0.312833 -0.352416
#
# [5 rows x 52 columns]

# %%
conn = sqlite3.connect(db_path.as_posix())
df_final.to_sql("Player_Formation_Preprocessed", conn, if_exists="replace", index=False)
conn.close()
